# %% [markdown]
# # 🔍 Gradient Edge Detection using Sobel Operator (OpenCV)
#
# In this notebook, we'll perform **gradient-based edge detection** using the **Sobel operator** in OpenCV.
#
# ---
#
# ## 📌 Objective
# To detect edges in an image by computing the gradient in both X and Y directions, and combining them to obtain an edge map.
#
# ---
#
# ## 🧠 Key Concepts
#
# - **Gradient**: Measures change in intensity; sharp changes indicate edges.
# - **Sobel Operator**: A discrete differentiation operator that computes an approximation of the gradient.
#
# Sobel Kernels:
# - Gx:

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread("ForGradient.jpeg")

# %%
grad_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=3)  # ∂I/∂x
grad_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=3)

# %%
edge_map_x = cv2.convertScaleAbs(magnitude_x)
edge_map_y = cv2.convertScaleAbs(magnitude_y)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 magnitude_x = cv2.magnitude(grad_x)
#       2 edge_map_x = cv2.convertScaleAbs(magnitude_x)
#       3 magnitude_y = cv2.magnitude(grad_y)
#
# error: OpenCV(4.11.0) :-1: error: (-5:Bad argument) in function 'magnitude'
# > Overload resolution failed:
# >  - magnitude() missing required argument 'y' (pos 2)
# >  - magnitude() missing required argument 'y' (pos 2)

# %%
magnitude = cv2.magnitude(grad_x, grad_y)

edge_map = cv2.convertScaleAbs(magnitude)

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.title("Original Image")
plt.imshow(image, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title("Gradient Edge Map")
plt.imshow(edge_map, cmap='gray')
plt.axis('off')

plt.tight_layout()
plt.show()
